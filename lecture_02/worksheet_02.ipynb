# %% [markdown]
# # Worksheet 02
#
# Name:  Jiawei Sun
#
# UID: U81507478
#
# ### Topics
#
# - Effective Programming
#
# ### Effective Programming
#
# a) What is a drawback of the top down approach?

# %% [markdown]
# - Lack of ground-level understanding
# - Ineffective communication
# - Resistance to chang
# - Creativity and innovation constraints
# - Disconnect from real-world feedback

# %% [markdown]
# b) What is a drawback of the bottom up approach?

# %% [markdown]
# - Lack of Strategic Alignment
# - Potential for inefficiency
# - Difficulty in scaling
# - Lack of consistency
# - Potential for resistance to central authority
# - Resource constraints
# - Difficulty in prioritization
# - Risk of ignoring broader context

# %% [markdown]
# c) What are 3 things you can do to have a better debugging experience?

# %% [markdown]
# 1. Read the error
#     * What is the error telling you?
#     * Where did the error occur?
#     * Is this a cause or just a sympton
# 2. Re-read your code - take your time
#     * Mentally trace through the code to reproduce the error
# 3. Sanity check where you can
# 4. Look online for some help

# %% [markdown]
# d) Follow along with the live coding. You can write your code here:

# %%
class Board:
    def __init__(self):
        self.board = [["_" for _ in range(8)] for _ in range(8)]
        self.solutions = int()
    
    def __repr__(self):
        res = ""
        for row in self.board:
            for col in row:
                res += col
                res += " "
            res += "\n"
        return res

    def is_legal_row(self, row):
        for c in range(len(self.board[0])):
            if self.board[row][c] == "Q":
                return False
        return True
    
    def is_legal_col(self, col):
        for r in range(len(self.board)):
            if self.board[r][col] == "Q":
                return False
        return True
    
    def is_on_board(self, row, col):
        return row >= 0 and row < 8 and col >= 0 and col < 8

    def is_legal_diag(self, row, col):
        for i in range(len(self.board)):
            if self.is_on_board(row -i, col-i) and self.board[row-i][col-i] == "Q":
                return False
            if self.is_on_board(row +i, col+i) and self.board[row+i][col+i] == "Q":
                return False
            if self.is_on_board(row -i, col+i) and self.board[row-i][col+i] == "Q":
                return False
            if self.is_on_board(row +i, col-i) and self.board[row+i][col-i] == "Q":
                return False

        return True

    def is_legal(self, row, col):
        if not self.is_legal_row(row):
            return False
        
        if not self.is_legal_col(col):
            return False
        
        if not self.is_legal_diag(row, col):
            return False
        
        return True

    def set_queen_at(self, row, col):
        self.board[row][col] = "Q"

    def get_queen_on(self, row):
        for c in range(len(self.board[0])):
            if self.board[row][c] == "Q":
                return c
        raise ValueError("Programmer Error for finding a queen")

    def unset_queen_on(self, row):
        self.board[row] = ["_" for _ in range(8)]
    
    def search(self):
        row = 0
        col = 0
        self.solutions = 0

        while row >= 0:
            if row < 8:
                if self.is_legal(row, col):
                    self.set_queen_at(row, col)
                    row += 1
                    col = 0
                else:
                    col += 1
                    while col >= 8:
                        if row == 0:
                            return                        
                        col = self.get_queen_on(row-1)
                        self.unset_queen_on(row-1)
                        col += 1
                        row -= 1
            else:
                print("found solution")
                print(self)
                self.solutions += 1
                col = self.get_queen_on(row-1)
                self.unset_queen_on(row-1)
                col += 1
                row -= 1
                if row == 0:
                    return
                elif col >= 8:
                    col = self.get_queen_on(row-1)
                    self.unset_queen_on(row-1)
                    col += 1
                    row -= 1
                    if row == 0:
                        return

my_board = Board()
my_board.search()
print(my_board.solutions)
# Out:
# found solution
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
#
# found solution
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
#
# found solution
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
#
# found solution
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
#
# found solution
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
#
# found solution
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
#
# found solution
# ...
