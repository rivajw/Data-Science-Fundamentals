# %% [markdown]
# # Worksheet 03
#
# Name:
# UID:
#
# ### Topics
#
# - Intro to DS
#
# ### Linear Algebra Review
#
# If you need a linear algebra review, please read through the [following pdf](https://github.com/gallettilance/CS506-Spring2023/raw/main/worksheets/lecture_03_linear_algebra_review.pdf) before next class
#
# ### Intro to Data Science
#
# a) what property must a hypothesis have?

# %% [markdown]
# - Testability
# - Falsifiability
# - Specificity
# - Clarity
# - Relevance
# - Testable Predictions
# - Logical Consistency
# - Parsimony
# - Revisability
# - Test of Time
#
# A hypothesis should be a clear, testable, and falsifiable statement that serves as a starting point for scientific investigation. It should be designed to answer a specific research question and be based on a logical understanding of the subject matter.

# %% [markdown]
# b) what examples would you have wanted to try?

# %% [markdown]
# (0, 0, 0)

# %% [markdown]
# c) Poll 1

# %% [markdown]
# A

# %% [markdown]
# d) Given the hypothesis (x, 2x, 3x), for each of the following, determine whether they are positive or negative examples:
#
# - (2, 4, 6)
# - (6, 8 , 10)
# - (1, 3, 5)

# %% [markdown]
# - (2, 4, 6) -> Positive
# - (6, 8 , 10) -> Negative
# - (1, 3, 5) -> Negative

# %% [markdown]
# e) Poll 2

# %% [markdown]
# C
#
# We are tying a negative example here to narrow down the range

# %% [markdown]
# f) Describe steps of a Data Science Workflow

# %%
from IPython.display import Image
Image(filename = "f.jpg")

# %% [markdown]
# g) Give a real world example for each of the following data types:
#
# - record
# - graph
# - image
# - text

# %% [markdown]
# - record:
#     * m-dimensional points / vectors
#     * A bank account record for a US citizon
# - graph
#     * Nodes connected by edges
#     * Social network friendship graph
# - image: satellite image of earth
#     * A matrix of pixels (in rgb value)
#     * A images of dog
# - text: news article
#     * Words in documents. Can be stored in a matrix, with col = word, row = document, (d, w) = whether the word w exists in the document d
#     * A news article

# %% [markdown]
# h) Give a real world example of unsupervised learning

# %% [markdown]
# A Supermarket tried to model the products that customers required most often. They collect custoners' gender,

# %% [markdown]
# i) Give a real world example of supervised learning

# %% [markdown]
# Email providers use supervised learning algorithms to automatically classify incoming emails as either "spam" or "not spam".
